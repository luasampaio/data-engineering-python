# %%
import pandas as pd

# %%
import pandas as pd

df = pd.read_csv('part-00000-tid-3351659048830145827-af49f539-59c6-4687-aa36-061a5a0af19b-472-1-c000.csv')

# %%
df.head()
# Out:
#             CHAMADO                  STATUS PRODUTO    DESCRICAO_PRODUTO  \
# 0  PSQ2024000071561  PesqSat_AgClassOuvUnid     Psa    Emergência Adulta
# 1  PSQ2024000071566  PesqSat_AgClassOuvUnid     Psa    Emergência Adulta
# 2  PSQ2024000071569  PesqSat_AgClassOuvUnid     Psa    Emergência Adulta
# 3  PSQ2024000071586  PesqSat_AgClassOuvUnid     Psa    Emergência Adulta
# 4  PSQ2024000071559  PesqSat_AgClassOuvUnid     Psi  Emergência Infantil
#
#                               PROCESSO DESCRICAO_PROCESSO  \
# 0  Atendimento Médico - Clínica Médica              vazio
# 1                           Tomografia              vazio
# 2  Atendimento Médico - Clínica Médica              vazio
# 3                      Avaliação Geral              vazio
# 4  Atendimento Médico - Clínica Médica              vazio
#
#                   PROBLEMA DESCRICAO_PROBLEMA          LOCALIDADE_SOLICITACAO  \
# 0                  Postura              vazio  PE - Hospital Esperança Recife
# ...

# %%
import pandas as pd

# Carregar o arquivo CSV
csv_file = "seu_arquivo.csv"  # Substitua pelo nome do seu arquivo
df = pd.read_csv(csv_file)

# Salvar como Excel
excel_file = "seu_arquivo.xlsx"  # Nome do arquivo de saída
df.to_excel(excel_file, index=False)

print(f"Arquivo convertido e salvo como {excel_file}")
